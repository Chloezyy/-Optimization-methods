# %%
from MyFunc import Func
from Solver import Solver
from numpy import *
import scipy.linalg as la
import matplotlib.pyplot as plt
import scipy.optimize as opt
import numpy.linalg as la
import time
from matplotlib import cm

# %% [markdown]
# 1-dimensional smooth function, using Golden Section Search method & Powell & DH，all methods work

# %%
x_range = [[-10],[10]] 
test_fuc = Func('Sphere',1,x_range) 
test_solver = Solver('Golden',test_fuc)
test_solver.solve() 
test_fuc.draw_func(show_finding=True)
plt.show()
# Out:
# Golden Iterations: 21 times
# Final x: 3.305348067594794e-05
# Final f(x): 0.00000

# %% [markdown]
# Golden -- time & precision

# %%
t0 = time.time()
test_solver = Solver('Golden',test_fuc) 
test_solver.golden()
t1 = time.time()
print("{} sec.".format(t1 - t0))
# Out:
# 0.0004780292510986328 sec.

# %%
la.norm(0 - test_solver.golden())
# Out:
# 3.305348067594794e-05

# %% [markdown]
# Golden serach section in 1d using scipy  package

# %%
# %time opt.golden(lambda x: sum(x*x), brack=(-10, 10))
# Out:
# CPU times: user 7.04 ms, sys: 501 µs, total: 7.55 ms
# Wall time: 7.21 ms
# -1.5717277768849392e-162

# %%
la.norm(0 - opt.golden(lambda x: sum(x*x), brack=(-10, 10)))
# Out:
# 0.0

# %% [markdown]
# Powell can also work on 1d

# %%
x_range = [[-10],[10]]
test_fuc = Func('Sphere',1,x_range)
test_solver = Solver('Powell',test_fuc)
test_solver.solve()
test_fuc.draw_func(show_finding=True)
plt.show()
# Out:
# Powell Iterations: 149 times
# Final x: [-3.52869863e-12]
# Final f(x): 0.00000

# %%
t0 = time.time()
test_solver = Solver('Powell',test_fuc) 
test_solver.powell()
t1 = time.time()
print("{} sec.".format(t1 - t0))
# Out:
# 0.002780914306640625 sec.

# %%
la.norm(0 - test_solver.powell())
# Out:
# 4.557497120438341e-12

# %% [markdown]
# Powell Scipy

# %%
# %time opt.minimize(lambda x: sum(x*x), 10,  method='Powell',options={'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 2
#          Function evaluations: 28
# CPU times: user 1.07 ms, sys: 531 µs, total: 1.6 ms
# Wall time: 1.28 ms
#    direc: array([[1.]])
#      fun: 1.262177448353619e-29
#  message: 'Optimization terminated successfully.'
#     nfev: 28
#      nit: 2
#   status: 0
#  success: True
#        x: array([3.55271368e-15])

# %%
la.norm(0 - opt.minimize(lambda x: sum(x*x), 10,  method='Powell').x)
# Out:
# 3.552713678800501e-15

# %% [markdown]
# Down Hill

# %%
x_range = [[-10],[10]]
test_fuc = Func('Sphere',1,x_range)
test_solver = Solver('DownHill',test_fuc)
test_solver.solve()
test_fuc.draw_func(show_finding=True)
plt.show()
# Out:
# DownHill Iterations: 58 times
# Final x: [-5.46229728e-12]
# Final f(x): 0.00000

# %%
t0 = time.time()
test_solver = Solver('DownHill',test_fuc) 
test_solver.downhill()
t1 = time.time()
print("{} sec.".format(t1 - t0))
# Out:
# 0.003378152847290039 sec.

# %%
la.norm(0 - test_solver.downhill())
# Out:
# 1.6836665395203454e-10

# %% [markdown]
# Down Hill using scipy package for 1d

# %%
# %time opt.minimize(lambda x: sum(x*x), 10, method='nelder-mead', options={'xatol': 1e-4, 'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 42
# CPU times: user 2.21 ms, sys: 1.41 ms, total: 3.62 ms
# Wall time: 3.17 ms
#  final_simplex: (array([[ 0.00000000e+00],
#        [-6.10351562e-05]]), array([0.0000000e+00, 3.7252903e-09]))
#            fun: 0.0
#        message: 'Optimization terminated successfully.'
#           nfev: 42
#            nit: 21
#         status: 0
#        success: True
#              x: array([0.])

# %%
la.norm(0 - opt.minimize(lambda x: sum(x*x), 10,  method='nelder-mead').x)
# Out:
# 0.0

# %% [markdown]
# Gradient

# %%
x_range = [[-10],[10]]
test_fuc = Func('Sphere',1,x_range)
test_solver = Solver('Gradient',test_fuc)
test_solver.solve()
test_fuc.draw_func(show_finding=True)
plt.show()
# Out:
# Gradient Iterations: 348 times
# Final x: [4.33645867e-11]
# Final f(x): 0.00000

# %%
t0 = time.time()
test_solver = Solver('Gradient',test_fuc) 
test_solver.gradient()
t1 = time.time()
print("{} sec.".format(t1 - t0))
# Out:
# 0.006289005279541016 sec.

# %%
la.norm(0 - test_solver.gradient())
# Out:
# 4.79236484427085e-11

# %% [markdown]
# 2-dimensional smooth function, using Golden Section Search method & Powell & DH

# %% [markdown]
# Golden Search section

# %%
x_range = [[-10,-10],[10,10]]
test_fuc = Func('Sphere',2,x_range)
test_solver = Solver('Golden',test_fuc)
test_solver.solve() 
test_fuc.draw_func(show_finding=True)
plt.show()
# Out:
# Problem Dim is greater than 1, Golden method can not solve it.
# Golden Iterations: 21 times
# Final x: 3.305348067594794e-05
# Final f(x): 0.00000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-3074f1406e89> in <module>
#       3 test_solver = Solver('Golden',test_fuc)
#       4 test_solver.solve()
# ----> 5 test_fuc.draw_func(show_finding=True)
#       6 plt.show()
#
# ~/Desktop/Project/MyFunc.py in draw_func(self, show_finding)
#      83                 for i in range(rem_num):
#      84                     y = self.prb_func(np.array(self.x_rem[i]))
# ---> 85                     X1[i] = self.x_rem[i][0]
#      86                     X2[i] = self.x_rem[i][1]
#      87                     Y[i] = y
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %% [markdown]
# Golden method cannot be implemented in multidimensional

# %% [markdown]
# Powell's method for 2d function

# %%
x_range = [[-10,-10],[10,10]]
test_fuc = Func('Sphere',2,x_range) 
test_solver = Solver('Powell',test_fuc)
test_solver.solve() 
test_fuc.draw_func(show_finding=True)
plt.show()
# Out:
# Powell Iterations: 1888 times
# Final x: [-1.68012999e-11 -8.72928075e-12]
# Final f(x): 0.00000

# %%
t0 = time.time()
test_solver = Solver('Powell',test_fuc) 
test_solver.powell()
t1 = time.time()
print("{} sec.".format(t1 - t0))
# Out:
# 0.06076383590698242 sec.

# %%
la.norm(0 - test_solver.powell())
# Out:
# 0.00016945156050464998

# %% [markdown]
# Powell's method using scipy.optimization package

# %%
# %time opt.minimize(lambda x: sum(x*x), [[10],[10]],  method='Powell',options={'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 2
#          Function evaluations: 38
# CPU times: user 1.12 ms, sys: 249 µs, total: 1.37 ms
# Wall time: 1.2 ms
#    direc: array([[1., 0.],
#        [0., 1.]])
#      fun: 1.681851449931197e-27
#  message: 'Optimization terminated successfully.'
#     nfev: 38
#      nit: 2
#   status: 0
#  success: True
#        x: array([4.08562073e-14, 3.55271368e-15])

# %%
la.norm([[0],[0]] - opt.minimize(lambda x: sum(x*x), [[10],[10]],  method='Powell').x)
# Out:
# 5.799743873536481e-14

# %% [markdown]
# Down Hill for 2d funciton

# %%
x_range = [[-10,-10],[10,10]]
test_fuc = Func('Sphere',2,x_range)
test_solver = Solver('DownHill',test_fuc)
test_solver.solve()
test_fuc.draw_func(show_finding=True)
plt.show()
# Out:
# DownHill Iterations: 687 times
# Final x: [-0.20356747  1.89779922]
# Final f(x): 3.64308

# %%
t0 = time.time()
test_solver = Solver('DownHill',test_fuc) 
test_solver.downhill()
t1 = time.time()
print("{} sec.".format(t1 - t0))
# Out:
# 0.06675505638122559 sec.

# %%
la.norm(0 - test_solver.downhill())
# Out:
# 0.037525290788664706

# %% [markdown]
# Down Hill using scipy.optimisation package

# %%
# %time opt.minimize(lambda x: sum(x*x), [[10],[10]], method='nelder-mead', options={'xatol': 1e-4, 'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 46
#          Function evaluations: 83
# CPU times: user 4.03 ms, sys: 2.36 ms, total: 6.38 ms
# Wall time: 5.09 ms
#  final_simplex: (array([[ 1.49644896e-05,  2.14267502e-05],
#        [-6.66102636e-05, -3.87651420e-05],
#        [-4.35018680e-05,  6.96203364e-05]]), array([6.83041572e-10, 5.93966346e-09, 6.73940376e-09]))
#            fun: 6.830415723986571e-10
#        message: 'Optimization terminated successfully.'
#           nfev: 83
#            nit: 46
#         status: 0
#        success: True
#              x: array([1.49644896e-05, 2.14267502e-05])

# %%
la.norm([[0],[0]] - opt.minimize(lambda x: sum(x*x), [[10],[10]],  method='nelder-mead').x)
# Out:
# 3.696056201950011e-05

# %% [markdown]
# Rosenbrock function

# %%
x_range = [[-10,-10],[10,10]]
test_fuc = Func('Rosenbrock',2,x_range) 
test_solver = Solver('Powell',test_fuc) 
test_solver.solve() 
test_fuc.draw_func(show_finding=True) 
plt.show()
# Out:
# Powell Iterations: 15357 times
# Final x: [1.5220567  2.29913887]
# Final f(x): 0.30323

# %%
t0 = time.time()
test_solver = Solver('Powell',test_fuc) 
test_solver.powell()
t1 = time.time()
print("{} sec.".format(t1 - t0))
# Out:
# 0.014917850494384766 sec.

# %%
la.norm(0 - test_solver.powell())
# Out:
# 0.7867905385563128

# %% [markdown]
# Powell using scipy optimization package

# %%
# %time opt.minimize(lambda x: sum(100 * square(x[1:len(x)] - square(x[0:len(x) - 1]))) + sum(square(x[0:len(x) - 1] - 1)), [[10],[10]],  method='Powell',options={'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 2.496710
#          Iterations: 14
#          Function evaluations: 395
# CPU times: user 12.7 ms, sys: 626 µs, total: 13.4 ms
# Wall time: 13.1 ms
#    direc: array([[-0.01548723, -0.08923154],
#        [-0.52830368, -3.05977971]])
#      fun: 2.49671031211749
#  message: 'Optimization terminated successfully.'
#     nfev: 395
#      nit: 14
#   status: 0
#  success: True
#        x: array([2.56260506, 6.54349778])

# %%
la.norm([[0],[0]] - opt.minimize(lambda x: sum(100 * square(x[1:len(x)] - square(x[0:len(x) - 1]))) + sum(square(x[0:len(x) - 1] - 1)), [[10],[10]],  method='Powell').x)
# Out:
# 9.938240076421769

# %% [markdown]
# Down Hill

# %%
x_range = [[-10,-10],[10,10]]
test_fuc = Func('Rosenbrock',2,x_range)
test_solver = Solver('DownHill',test_fuc)
test_solver.solve()
test_fuc.draw_func(show_finding=True)
plt.show()
# Out:
# DownHill Iterations: 2009 times
# Final x: [0.29355641 0.05498749]
# Final f(x): 0.59633

# %%
t0 = time.time()
test_solver = Solver('DownHill',test_fuc) 
test_solver.downhill()
t1 = time.time()
print("{} sec.".format(t1 - t0))
# Out:
# 0.09892034530639648 sec.

# %%
la.norm(0 - test_solver.downhill())
# Out:
# 5.871216192923293

# %%
# %time opt.minimize(lambda x: sum(100 * square(x[1:len(x)] - square(x[0:len(x) - 1]))) + sum(square(x[0:len(x) - 1] - 1)), [[10],[10]], method='nelder-mead', options={'xatol': 1e-4, 'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 129
#          Function evaluations: 235
# CPU times: user 12.5 ms, sys: 4.94 ms, total: 17.4 ms
# Wall time: 13.6 ms
#  final_simplex: (array([[0.99998163, 0.99996285],
#        [0.99999347, 0.99998899],
#        [1.00002121, 1.00004044]]), array([3.55081863e-10, 4.63974805e-10, 8.44382082e-10]))
#            fun: 3.550818625380142e-10
#        message: 'Optimization terminated successfully.'
#           nfev: 235
#            nit: 129
#         status: 0
#        success: True
#              x: array([0.99998163, 0.99996285])

# %%
la.norm([[0],[0]] - opt.minimize(lambda x: sum(100 * square(x[1:len(x)] - square(x[0:len(x) - 1]))) + sum(square(x[0:len(x) - 1] - 1)), [[10],[10]],  method='nelder-mead').x)
# Out:
# 1.999944478638788

# %% [markdown]
# Plot Rosenbrock

# %%
b = 10;
f = lambda x,y: (x-1)**2 + b*(y-x**2)**2;

# %%
# Initialize figure 
figRos = plt.figure(figsize=(12, 7))
axRos = figRos.gca(projection='3d')

# Evaluate function
X = arange(-2, 2, 0.15)
Y = arange(-1, 3, 0.15)
X, Y = meshgrid(X, Y)
Z = f(X,Y)

# Plot the surface
surf = axRos.plot_surface(X, Y, Z, cmap=cm.gist_heat_r,
                       linewidth=0, antialiased=False)
axRos.set_zlim(0, 200)
figRos.colorbar(surf, shrink=0.5, aspect=10)
plt.show()

# %% [markdown]
# Schwefel2

# %%
x_range = [[-10,-10],[10,10]]
test_fuc = Func('Schwefel2',2,x_range)
test_solver = Solver('Powell',test_fuc)
test_solver.solve()
test_fuc.draw_func(show_finding=True)
plt.show()
# Out:
# Powell Iterations: 11432 times
# Final x: [-1.91369123e-05  2.04079870e-05]
# Final f(x): 0.00000

# %%
t0 = time.time()

test_fuc = Func('Schwefel2', 2,x_range)

test_solver = Solver('Powell',test_fuc) 
test_solver.powell()
t1 = time.time()
print("{} sec.".format(t1 - t0))
# Out:
# 0.12033891677856445 sec.

# %%
la.norm(0 - test_solver.powell())
# Out:
# 0.0013592814356808214

# %% [markdown]
# DH

# %%
x_range = [[-10,-10],[10,10]]
test_fuc = Func('Schwefel2',2,x_range)
test_solver = Solver('DownHill',test_fuc)
test_solver.solve()
test_fuc.draw_func(show_finding=True)
plt.show()
# Out:
# DownHill Iterations: 1973 times
# Final x: [-0.2689304  -0.04739614]
# Final f(x): 0.17239

# %%
t0 = time.time()
test_fuc = Func('Schwefel2', 2,x_range)
test_solver = Solver('DownHill',test_fuc) 
test_solver.downhill()
t1 = time.time()
print("{} sec.".format(t1 - t0))
# Out:
# 0.09903478622436523 sec.

# %%
la.norm(0 - test_solver.downhill())
# Out:
# 3.248827963298782e-05

# %%
def schwefel( x1,x2):  
    return 418.9829*2 - x1 * sin( sqrt( abs( x1 )))-x2*sin(sqrt(abs(x2)))

x1=linspace(-50,50)
x2=linspace(-50,50)
r_min,r_max=-50,50

x1,x2=np.meshgrid(x1,x2)
results=schwefel(x1,x2)
figure=plt.figure()
axis=figure.gca(projection='3d')
axis.plot_surface(x1,x2,results,color='green')
axis.plot_wireframe(x1,x2,results,color='rgb')
axis.set_xlabel('X')
axis.set_ylabel('Y')
axis.set_zlabel('Z')
plt.show()
# Out:
# <ipython-input-38-1e603410d600>:13: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated since 3.2 and will be removed two minor releases later. Use an explicit list instead.
#   axis.plot_wireframe(x1,x2,results,color='rgb')

# %% [markdown]
# General Rastrigin function

# %%
x_range = [[-10,-10],[10,10]]
test_fuc = Func('GRastrigin',2,x_range)
test_solver = Solver('Powell',test_fuc)
test_solver.solve()
test_fuc.draw_func(show_finding=True)
plt.show()
# Out:
# Powell Iterations: 835 times
# Final x: [5.9695722  2.98485553]
# Final f(x): 44.77259

# %%
t0 = time.time()

test_fuc = Func('GRastrigin', 2,x_range)

test_solver = Solver('Powell',test_fuc) 
test_solver.powell()
t1 = time.time()
print("{} sec.".format(t1 - t0))
# Out:
# 0.020138025283813477 sec.

# %%
la.norm(0 - test_solver.powell())
# Out:
# 7.959233690965837

# %% [markdown]
# DownHill

# %%
x_range = [[-10,-10],[10,10]]
test_fuc = Func('GRastrigin',2,x_range)
test_solver = Solver('DownHill',test_fuc)
test_solver.solve()
test_fuc.draw_func(show_finding=True)
plt.show()
# Out:
# DownHill Iterations: 967 times
# Final x: [1.96279484 2.99211042]
# Final f(x): 13.08957

# %%
t0 = time.time()
test_fuc = Func('GRastrigin', 2,x_range)
test_solver = Solver('DownHill',test_fuc) 
test_solver.downhill()
t1 = time.time()
print("{} sec.".format(t1 - t0))
# Out:
# 0.01728987693786621 sec.

# %%
la.norm(0 - test_solver.powell())
# Out:
# 9.949130659957657

# %%
# rastrigin graph

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm 
from mpl_toolkits.mplot3d import Axes3D 
 
X = np.linspace(-5.12, 5.12, 100)     
Y = np.linspace(-5.12, 5.12, 100)     
X, Y = np.meshgrid(X, Y) 

Z = (X**2 - 10 * np.cos(2 * np.pi * X)) + \
  (Y**2 - 10 * np.cos(2 * np.pi * Y)) + 20
 
fig = plt.figure() 
ax = fig.gca(projection='3d') 
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
  cmap=cm.nipy_spectral, linewidth=0.08,
  antialiased=True)    
# plt.savefig('rastrigin_graph.png')
plt.show()
